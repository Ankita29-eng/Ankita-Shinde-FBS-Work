# %% [markdown]
# ### Refer to the tips.csv dataset. The dataset contains total 244 tips(data about customers served by a restaurant) across 7 different columns.
# ####  totbill - Total bill (cost of the meal), including tax, in US dollars
# ####  tip - Tip (gratuity) in US dollars
# ####  sex - Sex of person paying for the meal (0=male, 1=female)
# ####  smoker - Smoker in party? (0=No, 1=Yes)
# ####  day - Sun, Sat, Thu, Fri
# ####  time - Night and Day
# ####  size - Size of the party

# %% [markdown]
# ### Q1. Plot a day wise boxplot of totbill column.

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df =pd.read_csv("C:/Users/Ankita shinde/OneDrive/Desktop/FBS/Data Analysis/DataSets/Datasets/tips.csv")
sns.boxplot(x="day", y="total_bill", data=df)

plt.title("Day wise Boxplot of total_bill")
plt.xlabel("day")
plt.ylabel("total_bill")

plt.show()
