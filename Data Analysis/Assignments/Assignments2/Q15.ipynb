# %% [markdown]
# #### Q15.Generate an array of 10 random integers between 1 and 50.

# %%
import numpy as np

# %%
arr = np.random.randint(1,51,size =10)

# %%
print("Random Array:")
print(arr)
# Out:
# Random Array:
# [32 13 16  5 29 33 14 20 40 34]
