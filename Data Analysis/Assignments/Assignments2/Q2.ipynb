# %% [markdown]
# #### Q2.Create a NumPy array from a given Python list [10,20,30,40,50].

# %%
import numpy as np

# %%
list1 = [10,20,30,40,50]
arr = np.array(list1)
print(arr)
# Out:
# [10 20 30 40 50]
